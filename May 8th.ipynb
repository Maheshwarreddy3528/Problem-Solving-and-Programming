# %%
print("hi")
# Out:
# hi

# %%
print(var2)
# Out:
# ...

# %%
print(len(str(var2)))
# Out:
# 51412

# %%
type(var1)
type("python")
# Out:
# str

# %%
str1 = "python programming"

str1[0]
str1[len(str1)-1]
str1[0:6]
str1[len(str1)-1::-1]
str1[0:len(str1):2]
str1[5::-2]
str1[7::] * 10
print(str1[7:] , str1[7:])
# Out:
# programming programming

# %%
li = [123, 345, 'python']
len(li)
li[2]
li[len(li)-1] = 'programming'
li.append('python')
#print(li)
li[2:] 
li.pop()
li.remove(345)
li.pop(0)
li.insert(0, 123)
li.insert(1, 345)
li2 = [[1,2,3],[4,5,6],[7,8,9]]
li2[1][1]
li2.insert(3,[10,11,12])
li2.pop(3)
li2.remove([7,8,9])
li2 = [[1,2,3],[4,5,6, 10],[7,8,9]]
li2[1].pop(3)
li.pop()
li.sort()
li.append(987)
li.append(534)
li.extend([765, 432, 999])
li.sort()
li
# Out:
# [123, 345, 432, 534, 765, 987, 999]

# %%
t1 = (123, 345, 567)
t1[2] + t1[1]
t1[len(t1)-1]
t1[1:3]
str(t1[0])[1] + " " + str(t1[1])[1] + " " + str(t1[2])[1]
t1 = (123, 345, 567)
str(t1[0])[2::-1] + str(t1[1])[2::-1] + str(t1[2])[2::-1]
# Out:
# '321543765'

# %%
str1 = input("enter a string")

str1
# Out:
# enter a stringpython
# 'python'

# %%
d1 = {'procedural':'C', 'scripting':'python', 'functional':'haskell'}

d1
d1['scripting']
d1.values()
d1.keys()
d2 = {'symbolic':'mathematica'}
d1.update(d2)
d1['objectoriented'] = 'java'
d1['logic']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-2d473efb0288> in <module>
#       8 d1.update(d2)
#       9 d1['objectoriented'] = 'java'
# ---> 10 d1['logic']
#
# KeyError: 'logic'

# %%
str1[7::] * 100
# Out:
# '...'
